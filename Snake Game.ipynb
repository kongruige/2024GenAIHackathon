# %%
# !git clone https://github.com/Poly186-AI-DAO/AutoGen-Snake-Game.git
# Out:
# Cloning into 'AutoGen-Snake-Game'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 81 (delta 16), reused 74 (delta 11), pack-reused 0
# Receiving objects: 100% (81/81), 196.09 KiB | 4.08 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
# !ls
# Out:
# AutoGen-Snake-Game  sample_data

# %%
# !pip install -r AutoGen-Snake-Game/requirements.txt
# !pip install openai
# !pip install diskcache

# %%
# !python AutoGen-Snake-Game/snake_dev_team.py
# Out:
# Player (to chat_manager):
#
# Let's design and implement a snake game. I aim for it to be entertaining and challenging.
#
# --------------------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/content/AutoGen-Snake-Game/snake_dev_team.py", line 85, in <module>
#     player.initiate_chat(
#   File "/usr/local/lib/python3.10/dist-packages/autogen/agentchat/conversable_agent.py", line 521, in initiate_chat
#     self.send(self.generate_init_message(**context), recipient, silent=silent)
#   File "/usr/local/lib/python3.10/dist-packages/autogen/agentchat/conversable_agent.py", line 324, in send
#     recipient.receive(message, self, request_reply, silent)
#   File "/usr/local/lib/python3.10/dist-packages/autogen/agentchat/conversable_agent.py", line 452, in receive
#     reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
# ...

# %%
# !cp AutoGen-Snake-Game/OAI_CONFIG_LIST.json /
